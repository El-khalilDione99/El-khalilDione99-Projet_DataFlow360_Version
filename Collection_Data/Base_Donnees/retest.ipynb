# %%
# les Dépendases
import pandas as pd

# %%
#Chargement du dataset
df = pd.read_csv('../générator/dataset_cardiovasculaire_senegal.csv')

df.sample(5)
# Out:
#        patient_id sexe  age region       milieu        profession  \
# 167014   SN167015    F   54  Kolda        Rural  Secteur informel
# 647152   SN647153    M   47  Dakar       Urbain  Secteur informel
# 537819   SN537820    M   61  Matam  Semi-urbain          Commerce
# 440168   SN440169    F   22  Thiès       Urbain  Secteur informel
# 860116   SN860117    F   72  Dakar       Urbain  Secteur informel
#
#        niveau_education  pression_arterielle_systolique  \
# 167014       Secondaire                             133
# 647152         Primaire                             117
# 537819            Aucun                             144
# 440168        Supérieur                             100
# 860116         Primaire                             170
#
#         pression_arterielle_diastolique  hypertension  ...  \
# 167014                               86             0  ...
# 647152                               73             0  ...
# ...
